# %% [markdown]
# # WangchanBERTa Fine-Tuning
#
# Verify the pipeline with `python -m src.models.train_transformer --debug --seed 42` before a full run.

# %%
import json
from pathlib import Path

metrics_path = Path('../reports/transformer_metrics.json')
json.loads(metrics_path.read_text(encoding='utf-8')) if metrics_path.exists() else 'Run Transformer training first.'
