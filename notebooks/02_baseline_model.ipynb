# %% [markdown]
# # Baseline Models
#
# The production training path is `python -m src.models.train_baseline --seed 42`.

# %%
import json
from pathlib import Path

metrics_path = Path('../reports/baseline_metrics.json')
json.loads(metrics_path.read_text(encoding='utf-8')) if metrics_path.exists() else 'Run the baseline CLI first.'
